# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.cluster import DBSCAN

# %%
data = pd.read_csv('test_Datda.csv')

# %%
data
# Out:
#                       vin  yearr  mmm  ddd  hr half_hour    avg_lat  \
# 0       MD9EMCDL24F217385   2025    1    1   4        h2  27.312450
# 1       MD9EMCDL24F217385   2025    1    1  16        h1  27.237260
# 2       MD9EMCDL24G217002   2025    1    1  12        h1  12.887503
# 3       MD9EMCDL24G217002   2025    1    1   8        h2  12.887571
# 4       MD9EMCDL24G217002   2025    1    1   2        h1  12.905336
# ...                   ...    ...  ...  ...  ..       ...        ...
# 154111  MD9EMHDL24H217108   2025    1    4  18        h1  28.654039
# 154112  MD9EMHDL24H217213   2025    1    4  12        h1  28.608850
# 154113  MD9EMHDL24J217110   2025    1    4  18        h1  28.479237
# 154114  MD9EMHDL24J217179   2025    1    4   5        h1  28.614929
# 154115  MD9EMHDL24K217089   2025    1    4  13        h2  28.495701
#
#          avg_long  avg_bat_charge
# 0       77.774628       84.000000
# 1       77.873297       38.200000
# 2       80.188916       93.909091
# 3       80.189537       95.000000
# 4       80.192095       97.571429
# ...           ...             ...
# 154111  77.041359       98.860001
# 154112  77.360039       69.320000
# 154113  77.191742       12.000000
# 154114  77.317177      100.000000
# 154115  77.343720        7.333333
#
# [154116 rows x 9 columns]

# %%
df = data.dropna()

# %%
df
# Out:
#                       vin  yearr  mmm  ddd  hr half_hour    avg_lat  \
# 0       MD9EMCDL24F217385   2025    1    1   4        h2  27.312450
# 1       MD9EMCDL24F217385   2025    1    1  16        h1  27.237260
# 2       MD9EMCDL24G217002   2025    1    1  12        h1  12.887503
# 3       MD9EMCDL24G217002   2025    1    1   8        h2  12.887571
# 4       MD9EMCDL24G217002   2025    1    1   2        h1  12.905336
# ...                   ...    ...  ...  ...  ..       ...        ...
# 154111  MD9EMHDL24H217108   2025    1    4  18        h1  28.654039
# 154112  MD9EMHDL24H217213   2025    1    4  12        h1  28.608850
# 154113  MD9EMHDL24J217110   2025    1    4  18        h1  28.479237
# 154114  MD9EMHDL24J217179   2025    1    4   5        h1  28.614929
# 154115  MD9EMHDL24K217089   2025    1    4  13        h2  28.495701
#
#          avg_long  avg_bat_charge
# 0       77.774628       84.000000
# 1       77.873297       38.200000
# 2       80.188916       93.909091
# 3       80.189537       95.000000
# 4       80.192095       97.571429
# ...           ...             ...
# 154111  77.041359       98.860001
# 154112  77.360039       69.320000
# 154113  77.191742       12.000000
# 154114  77.317177      100.000000
# 154115  77.343720        7.333333
#
# [153944 rows x 9 columns]

# %%
unique_values = df['vin'].unique()
print(len(unique_values))
# Out:
# 1237

# %%
count = df['vin'].value_counts()
# print(count)

# %%
count
# Out:
# vin
# MD9EMHDL23J217050    192
# MD9EMHDL23E217054    192
# MD9EMHDL22K217038    192
# MD9EMHDL22K217019    192
# MD9EMHDL23L217165    192
#                     ...
# MD9EMHDL24B217316      4
# MD9EMHDL24E217298      4
# MD9EMHDL24D217067      4
# MD9EMHDL23K217223      4
# MD9EMHDL23B217238      4
# Name: count, Length: 1237, dtype: int64

# %%
# Create a copy of the columns with correct names
date_cols = {
    'yearr': 'year',
    'mmm': 'month',
    'ddd': 'day',
    'hr': 'hour'
}
df_date = df[['yearr', 'mmm', 'ddd', 'hr']].rename(columns=date_cols)

# Create timestamp column
df['timestamp'] = pd.to_datetime(df_date)
# Out:
# C:\Users\vedpr\AppData\Local\Temp\ipykernel_16180\3722646221.py:11: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.head()
# Out:
#                  vin  yearr  mmm  ddd  hr half_hour    avg_lat   avg_long  \
# 0  MD9EMCDL24F217385   2025    1    1   4        h2  27.312450  77.774628
# 1  MD9EMCDL24F217385   2025    1    1  16        h1  27.237260  77.873297
# 2  MD9EMCDL24G217002   2025    1    1  12        h1  12.887503  80.188916
# 3  MD9EMCDL24G217002   2025    1    1   8        h2  12.887571  80.189537
# 4  MD9EMCDL24G217002   2025    1    1   2        h1  12.905336  80.192095
#
#    avg_bat_charge           timestamp  hour
# 0       84.000000 2025-01-01 04:00:00     4
# 1       38.200000 2025-01-01 16:00:00    16
# 2       93.909091 2025-01-01 12:00:00    12
# 3       95.000000 2025-01-01 08:00:00     8
# 4       97.571429 2025-01-01 02:00:00     2

# %%
print(df['timestamp'].head())
# Out:
# 0   2025-01-01 04:00:00
# 1   2025-01-01 16:00:00
# 2   2025-01-01 12:00:00
# 3   2025-01-01 08:00:00
# 4   2025-01-01 02:00:00
# Name: timestamp, dtype: datetime64[ns]

# %%
df['hour'] = df['timestamp'].dt.hour
night_df = df[(df['hour'] >= 0) & (df['hour'] < 5)]
# Out:
# C:\Users\vedpr\AppData\Local\Temp\ipykernel_16180\2292920831.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
print(night_df['vin'].value_counts())
# Out:
# vin
# MD9EMHDL23J217186    40
# MD9EMHDL23K217221    40
# MD9EMHDL24G217210    40
# MD9EMHDL23L217052    40
# MD9EMHDL23D217353    40
#                      ..
# MD9EMHDL24C217299     1
# MD9EMHDL24D217294     1
# MD9EMHDL23C217071     1
# MD9EMHDL24C217025     1
# MD9EMHDL23K217226     1
# Name: count, Length: 1088, dtype: int64

# %%
location_counts = (
    night_df.groupby(['vin', 'avg_lat', 'avg_long'])
    .size()
    .reset_index(name='count')
)

residence_location = (
    location_counts.sort_values('count', ascending=False)
    .drop_duplicates(subset='vin')
)

# %%
residence_location.to_excel('solution.xlsx', sheet_name='Q1_Residence_Location')

# %%
vin = 'MD9EMHDL23J217186'
vehicle_df = night_df[night_df['vin'] == vin]

# %%
from sklearn.cluster import DBSCAN

# %%
coords = vehicle_df[['avg_lat', 'avg_long']].to_numpy()

# DBSCAN: eps in degrees (~0.0005 ~ 50 meters), adjust as needed
clustering = DBSCAN(eps=0.0005, min_samples=2).fit(coords)

vehicle_df['cluster'] = clustering.labels_
# Out:
# C:\Users\vedpr\AppData\Local\Temp\ipykernel_16180\1909563296.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
vehicle_df.head()
# Out:
#                     vin  yearr  mmm  ddd  hr half_hour    avg_lat   avg_long  \
# 4112  MD9EMHDL23J217186   2025    1    1   2        h1  28.479519  77.295746
# 4115  MD9EMHDL23J217186   2025    1    1   0        h1  28.479464  77.295774
# 6519  MD9EMHDL23J217186   2025    1    1   4        h1  28.479432  77.295695
# 6526  MD9EMHDL23J217186   2025    1    1   0        h2  28.479329  77.295705
# 6527  MD9EMHDL23J217186   2025    1    1   1        h1  28.479210  77.295720
#
#       avg_bat_charge           timestamp  hour  cluster
# 4112           100.0 2025-01-01 02:00:00     2        0
# 4115           100.0 2025-01-01 00:00:00     0        0
# 6519           100.0 2025-01-01 04:00:00     4        0
# 6526           100.0 2025-01-01 00:00:00     0        0
# 6527           100.0 2025-01-01 01:00:00     1        0

# %%
plt.figure(figsize=(10, 6))

# Plot raw points
plt.scatter(vehicle_df['avg_long'], vehicle_df['avg_lat'], c='gray', s=30, label='Raw Points')

# Plot clusters with colors
for label in set(clustering.labels_):
    cluster_data = vehicle_df[vehicle_df['cluster'] == label]
    if label == -1:
        # Noise
        plt.scatter(cluster_data['avg_long'], cluster_data['avg_lat'], c='red', label='Noise', s=50, marker='x')
    else:
        plt.scatter(cluster_data['avg_long'], cluster_data['avg_lat'], label=f'Cluster {label}', s=50)

plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title(f"Night-Time GPS Clusters for Vehicle {vin}")
plt.legend()
plt.grid(True)
plt.show()

# %%
night_df[night_df['avg_lat']>90]
# Out:
#                       vin  yearr  mmm  ddd  hr half_hour        avg_lat  \
# 31      MD9EMCDL24G217011   2025    1    1   2        h2  197567.781400
# 34243   MD9EMHDL24D217173   2025    1    1   4        h2  124822.020300
# 36345   MD9EMHDL24J217227   2025    1    1   3        h2   52712.645160
# 140298  MD9EMHDL24F217029   2025    1    4   4        h2      96.702036
#
#          avg_long  avg_bat_charge           timestamp  hour
# 31      75.857829       82.260870 2025-01-01 02:00:00     2
# 34243   76.981448       99.000000 2025-01-01 04:00:00     4
# 36345   77.325057      100.000000 2025-01-01 03:00:00     3
# 140298   3.485430       97.008561 2025-01-04 04:00:00     4
